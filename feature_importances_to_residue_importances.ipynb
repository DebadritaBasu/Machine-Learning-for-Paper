# %%
# Setting file path
import os # Import the os module for file path handling

# Define the directory where your CSV files are located
data_directory = 'C:/Users/HP/Downloads/Machine-Learning-for-Paper-main/Machine-Learning-for-Paper-main/ml_data/' ## Remember to Change the path directory with your path

# %%
import pandas as pd

# %%
# Define the file name separately
file_name = 'feature_importances-processed.csv'

# Combine the directory path and file name to create the full file path
csv_file_path = os.path.join(data_directory, file_name)

# Check if the file path exists before loading the data
if os.path.exists(csv_file_path):
    # Load your data from CSV
    data = pd.read_csv(csv_file_path, header=None, names=['residue_1', 'residue_2', 'pairwise_distance_importance'])

    # Get a list of unique residues from both columns
    unique_residues = pd.unique(data[['residue_1', 'residue_2']].values.ravel('K'))

# Initialize a dictionary to store the cumulative importance for each residue
residue_importance_dict = {}

# Loop through each unique residue
for residue_id in unique_residues:
    # Filter data for the current residue in either column
    residue_data = data[(data['residue_1'] == residue_id) | (data['residue_2'] == residue_id)]
    
    # Calculate the sum of pairwise distance feature importances and divide by 2
    residue_importance = sum(residue_data['pairwise_distance_importance']) / 2
    
    # Store the importance for the current residue
    residue_importance_dict[residue_id] = residue_importance

# Print or analyze the residue-specific importances
for residue_id, importance in residue_importance_dict.items():
    print(f"Residue {residue_id} Importance: {importance}")
# Out:
# Residue ASP116 Importance: 0.0155
# Residue ASP120 Importance: 0.0
# Residue ASP127 Importance: 0.0
# Residue ASP160 Importance: 0.0
# Residue ASP199 Importance: 0.0002
# Residue ASP205 Importance: 0.01005
# Residue ASP211 Importance: 0.0
# Residue ASP218 Importance: 0.02115
# Residue ASP251 Importance: 0.00655
# Residue ASP306 Importance: 0.0
# Residue ASP322 Importance: 0.0
# Residue ASP327 Importance: 0.0
# Residue ASP33 Importance: 0.0
# Residue ASP345 Importance: 0.0
# Residue ASP367 Importance: 0.00505
# Residue ASP392 Importance: 0.0
# Residue ASP396 Importance: 0.0
# Residue ASP39 Importance: 0.0116
# Residue ASP424 Importance: 0.0
# Residue ASP431 Importance: 0.0
# Residue ASP463 Importance: 0.0037
# Residue ASP46 Importance: 0.0148
# Residue ASP476 Importance: 0.0067
# Residue ASP478 Importance: 0.0062
# Residue ASP47 Importance: 0.0132
# Residue ASP511 Importance: 0.0
# Residue ASP525 Importance: 0.0
# Residue ASP551 Importance: 0.0
# Residue ASP555 Importance: 0.0
# Residue ASP565 Importance: 0.01
# Residue ASP598 Importance: 0.0144
# Residue ASP614 Importance: 0.01565
# Residue ASP634 Importance: 0.00525
# Residue ASP640 Importance: 0.0
# Residue ASP646 Importance: 0.0
# Residue ASP661 Importance: 0.0
# Residue ASP686 Importance: 0.0185
# Residue ASP732 Importance: 0.0011
# Residue ASP741 Importance: 0.01065
# Residue ASP764 Importance: 0.00395
# Residue ASP76 Importance: 0.01865
# Residue ASP792 Importance: 0.013649999999999999
# Residue ASP854 Importance: 0.0
# Residue ASP864 Importance: 0.0
# Residue ASP98 Importance: 0.0223
# Residue GLU113 Importance: 0.0
# Residue GLU155 Importance: 0.0
# Residue GLU168 Importance: 0.0
# Residue GLU196 Importance: 0.01255
# Residue GLU207 Importance: 0.01595
# Residue GLU220 Importance: 0.0099
# Residue GLU22 Importance: 0.0
# Residue GLU279 Importance: 0.0
# Residue GLU27 Importance: 0.0
# Residue GLU284 Importance: 0.013250000000000001
# Residue GLU290 Importance: 0.0036
# Residue GLU297 Importance: 0.0
# Residue GLU386 Importance: 0.01705
# Residue GLU3 Importance: 0.00585
# Residue GLU411 Importance: 0.00555
# Residue GLU415 Importance: 0.0
# Residue GLU423 Importance: 0.0079
# Residue GLU429 Importance: 0.0
# Residue GLU433 Importance: 0.0038
# Residue GLU434 Importance: 0.00385
# Residue GLU440 Importance: 0.00405
# Residue GLU459 Importance: 0.010799999999999999
# Residue GLU464 Importance: 0.0043
# Residue GLU482 Importance: 0.00325
# Residue GLU545 Importance: 0.0
# Residue GLU55 Importance: 0.0141
# Residue GLU560 Importance: 0.0
# Residue GLU562 Importance: 0.0
# Residue GLU594 Importance: 0.0
# Residue GLU595 Importance: 0.0
# Residue GLU631 Importance: 0.0
# Residue GLU642 Importance: 0.0
# Residue GLU71 Importance: 0.012
# Residue GLU725 Importance: 0.0
# Residue GLU762 Importance: 0.012299999999999998
# Residue GLU765 Importance: 0.0149
# Residue GLU780 Importance: 0.0
# Residue GLU813 Importance: 0.00655
# Residue GLU820 Importance: 0.01375
# Residue GLU838 Importance: 0.0
# Residue GLU842 Importance: 0.0062
# Residue GLU849 Importance: 0.0
# Residue GLU858 Importance: 0.0
# Residue GLU90 Importance: 0.0
# Residue GLU97 Importance: 0.00925
# Residue GLU183 Importance: 0.00255
# Residue GLU254 Importance: 0.01055
# Residue GLU490 Importance: 0.01015
# Residue ASP245 Importance: 0.0056
# Residue GLU618 Importance: 0.01175
# Residue ARG156 Importance: 0.0
# Residue ARG121 Importance: 0.0
# Residue ARG123 Importance: 0.01155
# Residue LYS124 Importance: 0.0
# Residue LYS163 Importance: 0.01255
# Residue LYS166 Importance: 0.0002
# Residue ARG390 Importance: 0.01015
# Residue LYS304 Importance: 0.009
# Residue ARG214 Importance: 0.01315
# Residue ARG215 Importance: 0.02115
# Residue LYS280 Importance: 0.0155
# Residue ARG2 Importance: 0.0533
# Residue ARG308 Importance: 0.00795
# Residue ARG373 Importance: 0.005
# Residue LYS326 Importance: 0.0
# Residue ARG84 Importance: 0.00165
# Residue LYS60 Importance: 0.0116
# Residue LYS311 Importance: 0.0038
# Residue ARG229 Importance: 0.00505
# Residue ARG422 Importance: 0.0079
# Residue LYS40 Importance: 0.0005499999999999999
# Residue ARG264 Importance: 0.00385
# Residue LYS430 Importance: 0.0
# Residue ARG796 Importance: 0.02055
# Residue ARG757 Importance: 0.01155
# Residue ARG514 Importance: 0.0
# Residue ARG523 Importance: 0.0
# Residue LYS559 Importance: 0.0
# Residue ARG558 Importance: 0.0
# Residue LYS591 Importance: 0.0
# Residue LYS96 Importance: 0.0144
# Residue ARG105 Importance: 0.0032
# Residue ARG599 Importance: 0.0
# Residue ARG688 Importance: 0.025249999999999998
# Residue ARG828 Importance: 0.00645
# Residue ARG593 Importance: 0.0
# Residue ARG817 Importance: 0.0166
# Residue ARG650 Importance: 0.0
# Residue LYS611 Importance: 0.02465
# Residue LYS734 Importance: 0.01065
# Residue ARG713 Importance: 0.00495
# Residue ARG439 Importance: 0.05450000000000001
# Residue LYS689 Importance: 0.0074
# Residue ARG743 Importance: 0.0011
# Residue ARG221 Importance: 0.0271
# Residue LYS761 Importance: 0.0
# Residue ARG79 Importance: 0.0
# Residue ARG699 Importance: 0.0
# Residue ARG746 Importance: 0.0
# Residue LYS401 Importance: 0.0
# Residue LYS112 Importance: 0.00395
# Residue ARG243 Importance: 0.0
# Residue ARG320 Importance: 0.0
# Residue LYS338 Importance: 0.0036
# Residue ARG339 Importance: 0.0
# Residue ARG64 Importance: 0.00625
# Residue ARG402 Importance: 0.0
# Residue ARG499 Importance: 0.0002
# Residue LYS456 Importance: 0.0
# Residue ARG678 Importance: 0.0
# Residue ARG755 Importance: 0.0
# Residue ARG483 Importance: 0.0326
# Residue LYS540 Importance: 0.0
# Residue ARG719 Importance: 0.0
# Residue LYS816 Importance: 0.0
# Residue ARG827 Importance: 0.0062
# Residue LYS829 Importance: 0.0
# Residue LYS394 Importance: 0.0145
# Residue LYS352 Importance: 0.01055

# %%
# Define the directory where the sorted CSV file will be saved
output_file_name = os.path.join(data_directory, 'sorted_residue_importances.csv')

# Create the full file path by combining the directory and file name
output_file_path = os.path.join(output_directory, output_file_name)

sorted_residue_importances = sorted(residue_importance_dict.items(), key=lambda x: x[1], reverse=True)


# Create a DataFrame from the sorted importances
sorted_data = pd.DataFrame(sorted_residue_importances, columns=['Residue', 'Importance'])

# Write the sorted residue importances to the CSV file
sorted_data.to_csv(output_file_path, index=False)

print(f"Sorted residue importances have been written to '{output_file_path}'.")
# Out:
# Sorted residue importances have been written to 'C:/Users/HP/Downloads/Machine-Learning-for-Paper-main/Machine-Learning-for-Paper-main/ml_data/sorted_residue_importances.csv'.
